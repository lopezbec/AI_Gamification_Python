# %% [markdown]
# <a href="https://colab.research.google.com/github/lopezbec/AI_Gamification_Python/blob/main/appreviews.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#installing neccesary libraries
"""
# !pip install google-play-scraper
# !pip install app-store-scraper
# !pip install google-search-scraper-python
# !pip install pandas
"""

from google_play_scraper import app, search, Sort, reviews, reviews_all
from app_store_scraper import AppStore
from pprint import pprint
import pandas as pd
import numpy as np
import json
#static variables:
language = 'en'
countries = 'us'
appid = []

def searches(nameofSearch):
  result = search(
    nameofSearch,
    lang="en",  # defaults to 'en'
    country="us",  # defaults to 'us'
    n_hits=3  # defaults to 30 (= Google's maximum)
)
  return result

def getAppId(r):
  for d in r:
    id = (d['appId'])
    # appid.append(id)
    return id

def insertId(g, cont, rating):
  if rating == None:
    result, continuation_token = reviews(
    g,
    lang='en', # defaults to 'en'
    country='us', # defaults to 'us'
    sort=Sort.NEWEST, # defaults to Sort.NEWEST
    count=cont # defaults to 100
     # defaults to None(means all score)
  )
    return result
  else:
    result, continuation_token = reviews(
    g,
    lang='en', # defaults to 'en'
    country='us', # defaults to 'us'
    sort=Sort.NEWEST, # defaults to Sort.NEWEST
    count=cont, # defaults to 100
    filter_score_with=rating# defaults to None(means all score)
  )
    return result
 
def googleplay(a, ct, r):
  searches1 = searches(a)
  appId = getAppId(searches1)
  reviews = insertId(appId, ct, r)
  return reviews

#input 

print("AppleStore or GooglePlay? (A -> Apple store, G -> Google play")
store = input()
if store == "a" or store == "A":
  print("Input the name of the app")
  app = input()
  applereviews = AppStore(country="us", app_name=app)
  print("How many reviews?")
  count = int(input())
  applereviews.review(how_many=count)
  applereviews.reviews
  applestoredf = pd.DataFrame(np.array(applereviews.reviews),columns=['review'])
  applestoredf2 = applestoredf.join(pd.DataFrame(applestoredf.pop('review').tolist()))

  print("Visualize data? (Y/N?)")
  visu = input()
  if visu == "Y" or visu == "y":
    display(applestoredf2)
  else:
   print("No display")

  print("Export data? (Y/N?)")
  visu2 = input()
  if visu2 == "Y" or visu2 == "y":
    applestoredf2.to_csv('applestore-review.csv') 
  else:
    print("No export")

else:
  print("Input the name of the app")
  app = input()
  print("How many reviews?")
  count = int(input())
  print("Include specific Rating? (Y/N?)")
  cond = input()
  if cond == "Y" or cond == "y":
    print("Input the rating: (0-5)")
    rating = int(input())
  elif cond == "N" or cond == "n":
    print("default rating")
    rating = None
  else:
    print("default rating")
    rating = None

  googleplaydf = pd.DataFrame(np.array(googleplay(app, count, rating)),columns=['review'])
  googleplaydf2 = googleplaydf.join(pd.DataFrame(googleplaydf.pop('review').tolist()))

  print("Visualize data? (Y/N?)")
  visu = input()
  if visu == "Y" or visu == "y":
    display(googleplaydf2)
  else:
   print("No display")

  print("Export data? (Y/N?)")
  visu2 = input()
  if visu2 == "Y" or visu2 == "y":
    googleplaydf2.to_csv('googleplay-review.csv') 
  else:
    print("No export")
# Out:
# AppleStore or GooglePlay? (A -> Apple store, G -> Google play
# G
# Input the name of the app
# sololearn
# How many reviews?
# 50000
# Include specific Rating? (Y/N?)
# n
# default rating
# Visualize data? (Y/N?)
# y
#                                    reviewId        userName  \
# 0      d871e14c-44fd-43eb-a3d0-38135e558bd8  Ramtenki Sadhi
# 1      48f78256-d57a-4de8-8ef1-9203c1113913   Kim Fernandes
# 2      8ab5d066-798f-4b78-90cb-8a193b7dc674     Cinar Sever
# 3      efbaf290-19ac-4169-af63-8a18eaeb7a14   Timur Gorskiy
# 4      b4b646c3-ef89-4942-a07e-fedcee48b998      Ehiz Chris
# ...                                     ...             ...
# 49995  b2cc20b6-1207-4c27-9bda-47df467ed2d1   A Google user
# 49996  66a6af09-b24a-4314-80f8-1263ada76841   A Google user
# 49997  b81aaeaf-59f1-49dc-8ee2-0718da94e15b   A Google user
# 49998  943ba28c-05d0-4c40-9889-3e33fdf84653   A Google user
# 49999  f33cf41e-b838-4eca-823a-168d07cbe09d   A Google user
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/a-/ACB-R...
# 1      https://play-lh.googleusercontent.com/a-/ACB-R...
# 2      https://play-lh.googleusercontent.com/a-/ACB-R...
# 3      https://play-lh.googleusercontent.com/a-/ACB-R...
# 4      https://play-lh.googleusercontent.com/a/AGNmyx...
# ...                                                  ...
# 49995  https://play-lh.googleusercontent.com/EGemoI2N...
# 49996  https://play-lh.googleusercontent.com/EGemoI2N...
# 49997  https://play-lh.googleusercontent.com/EGemoI2N...
# 49998  https://play-lh.googleusercontent.com/EGemoI2N...
# 49999  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                                  content  score  \
# 0                                          free learning      5
# 1      So convenient for beginners to learn, very cle...      5
# 2            Doesn't work on samsung s20 fe 5g with wifi      2
# 3                            Very useful and unusual app      5
# 4      its really great that it teaches people how to...      5
# ...                                                  ...    ...
# 49995                                 good for beginners      5
# 49996                              sololearn is the best      5
# 49997  Nice, this is a good approach to learn somethi...      5
# 49998                                         pay to use      1
# 49999                                               nice      4
#
#        thumbsUpCount reviewCreatedVersion                  at  \
# 0                  0               4.39.0 2023-02-27 18:57:19
# 1                  0               4.39.0 2023-02-27 18:37:18
# 2                  0               4.39.0 2023-02-27 18:34:50
# 3                  0               4.39.0 2023-02-27 18:29:22
# 4                  0               4.39.0 2023-02-27 17:02:25
# ...              ...                  ...                 ...
# 49995              0                 None 2019-06-01 16:46:11
# 49996              0                2.5.5 2019-06-01 16:31:51
# 49997              0                2.5.5 2019-06-01 16:25:36
# 49998              0                2.5.2 2019-06-01 16:09:29
# 49999              0                2.5.2 2019-06-01 15:08:00
#
#                                             replyContent           repliedAt
# 0                                                   None                 NaT
# 1                                                   None                 NaT
# 2                                                   None                 NaT
# 3                                                   None                 NaT
# 4                                                   None                 NaT
# ...                                                  ...                 ...
# 49995                                               None                 NaT
# 49996                                               None                 NaT
# 49997                                               None                 NaT
# 49998  This is to inform you that SoloLearn is comple... 2019-06-04 13:30:32
# 49999                                               None                 NaT
#
# [50000 rows x 10 columns]
# Export data? (Y/N?)
# Y
# Warning: total number of rows (50000) exceeds max_rows (20000). Limiting to first (20000) rows.
# Warning: total number of rows (50000) exceeds max_rows (20000). Limiting to first (20000) rows.
