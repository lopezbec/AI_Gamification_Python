# %%
import pandas as pd
import numpy as np
import csv
import os
import sys
from stemming.porter2 import stem
# res = []
# for word in words:
#     stemmed_word = stem(word)
#     res.append(stemmed_word)

# print(res)

# %%
with open('features.txt') as file:
    lines = file.read()

features = [token.strip() for token in lines.split(",")]

#features = [line.strip() for line in lines]
print(features)

filelist = [file for file in os.listdir('../review-files-sentiment/')]


for file in filelist:

    print(file)
    # create a sample dataframe
    df = pd.read_csv('../review-files-sentiment/' + file)
    # df = df.rename(columns={"review": "content", "score": "rating", "at": "date"})

    # define a set of strings to search for
    # stems = set(res) # {'apple', 'orange', 'mango'}
    #df['matched_stem'] = df['content'].str.findall('|'.join(stems)).apply(lambda x: ', '.join(x) if len(x) > 0 else None)
    #df = df.dropna()

    #df['matched_stem'] = df['content'].apply(lambda x: [] if x is None else [stem for stem in stems if stem in x])
    df['matched_feature'] = df['content'].apply(lambda x: [] if pd.isna(x) or x == '' else [feature for feature in features if feature in x])
    
    df = df[df['matched_feature'].apply(len) > 0]
    df['matched_feature'] = df['matched_feature'].apply(lambda x: ', '.join(x))
    
    output_file = os.path.splitext(file)[0] + "_features.csv"
    
    df.to_csv('review-files-features/' + output_file, index=False)

    print('Feature matching completed and saved to:', output_file)

# %%
with open('feature-words.txt') as file:
    lines = file.read()

feature_words = [token.strip() for token in lines.split(",")]
print(feature_words)

stems = []
for word in feature_words:
    stemmed_word = stem(word)
    stems.append(stemmed_word)

print(stems)

with open('feature-stems.txt', 'w') as file:

    for stem in stems:
        file.write(stem + ',')

# %%
stems = set(stems)

filelist = [file for file in os.listdir('../review-files-sentiment/')]

for file in filelist:

    print(file)
    # create a sample dataframe
    df = pd.read_csv('../review-files-sentiment/' + file)
    # df = df.rename(columns={"review": "content", "score": "rating", "at": "date"})

    # define a set of strings to search for
    # stems = set(res) # {'apple', 'orange', 'mango'}
    #df['matched_stem'] = df['content'].str.findall('|'.join(stems)).apply(lambda x: ', '.join(x) if len(x) > 0 else None)
    #df = df.dropna()

    #df['matched_stem'] = df['content'].apply(lambda x: [] if x is None else [stem for stem in stems if stem in x])
    df['matched_stem'] = df['content'].apply(lambda x: [] if pd.isna(x) or x == '' else [stem for stem in stems if stem in x])
    
    df = df[df['matched_stem'].apply(len) > 0]
    df['matched_stem'] = df['matched_stem'].apply(lambda x: ', '.join(x))
    
    output_file = os.path.splitext(file)[0] + "_stems.csv"
    
    df.to_csv('review-files-python-stems/' + output_file, index=False)

    print('Stem matching completed and saved to:', output_file)

# %%
with open('feature-synonyms.txt') as file:
    lines = file.read()

synonyms = [token.strip() for token in lines.split(",")]

print(synonyms)


filelist = [file for file in os.listdir('../review-files-sentiment/')]


for file in filelist:

    print(file)
    # create a sample dataframe
    df = pd.read_csv('../review-files-sentiment/' + file)
    # df = df.rename(columns={"review": "content", "score": "rating", "at": "date"})

    # define a set of strings to search for
    # stems = set(res) # {'apple', 'orange', 'mango'}
    #df['matched_stem'] = df['content'].str.findall('|'.join(stems)).apply(lambda x: ', '.join(x) if len(x) > 0 else None)
    #df = df.dropna()

    #df['matched_stem'] = df['content'].apply(lambda x: [] if x is None else [stem for stem in stems if stem in x])
    df['matched_synonym'] = df['content'].apply(lambda x: [] if pd.isna(x) or x == '' else [synonym for synonym in synonyms if synonym in x])
    
    df = df[df['matched_synonym'].apply(len) > 0]
    df['matched_synonym'] = df['matched_synonym'].apply(lambda x: ', '.join(x))
    
    output_file = os.path.splitext(file)[0] + "_synonyms.csv"
    
    df.to_csv('review-files-python-synonyms/' + output_file, index=False)

    print('Synonym matching completed and saved to:', output_file)

# %%
filelist = [file for file in os.listdir('../review-files-sentiment/')]

pythons = ['python']

for file in filelist:

    print(file)
    # create a sample dataframe
    df = pd.read_csv('../review-files-sentiment/' + file)
    df = df.rename(columns={"review": "content", "score": "rating", "at": "date"})

    # define a set of strings to search for
    # stems = set(res) # {'apple', 'orange', 'mango'}
    #df['matched_stem'] = df['content'].str.findall('|'.join(stems)).apply(lambda x: ', '.join(x) if len(x) > 0 else None)
    #df = df.dropna()

    #df['matched_stem'] = df['content'].apply(lambda x: [] if x is None else [stem for stem in stems if stem in x])
    df['matched_python'] = df['content'].apply(lambda x: [] if pd.isna(x) or x == '' else [python for python in pythons if python in x])
    
    df = df[df['matched_python'].apply(len) > 0]
    df['matched_python'] = df['matched_python'].apply(lambda x: ', '.join(x))
    
    output_file = os.path.splitext(file)[0] + "_python.csv"
    
    df.to_csv('review-files-python/' + output_file, index=False)

    print('Python matching completed and saved to:', output_file)

# %%
with open('features.txt') as file:
    lines = file.read()

features = [token.strip() for token in lines.split(",")]

#features = [line.strip() for line in lines]
print(features)

filelist = [file for file in os.listdir('./review-files-python/')]


for file in filelist:

    print(file)
    # create a sample dataframe
    df = pd.read_csv('./review-files-python/' + file)
    # df = df.rename(columns={"review": "content", "score": "rating", "at": "date"})

    # define a set of strings to search for
    # stems = set(res) # {'apple', 'orange', 'mango'}
    #df['matched_stem'] = df['content'].str.findall('|'.join(stems)).apply(lambda x: ', '.join(x) if len(x) > 0 else None)
    #df = df.dropna()

    #df['matched_stem'] = df['content'].apply(lambda x: [] if x is None else [stem for stem in stems if stem in x])
    df['matched_feature'] = df['content'].apply(lambda x: [] if pd.isna(x) or x == '' else [feature for feature in features if feature in x])
    
    df = df[df['matched_feature'].apply(len) > 0]
    df['matched_feature'] = df['matched_feature'].apply(lambda x: ', '.join(x))
    
    output_file = os.path.splitext(file)[0] + "_features.csv"
    
    df.to_csv('review-files-python-features/' + output_file, index=False)

    print('Feature matching completed and saved to:', output_file)

# %%
with open('feature-words.txt') as file:
    lines = file.read()

feature_words = [token.strip() for token in lines.split(",")]
print(feature_words)

stems = []
for word in feature_words:
    stemmed_word = stem(word)
    stems.append(stemmed_word)

print(stems)

with open('feature-stems.txt', 'w') as file:

    for stem in stems:
        file.write(stem + ',')

# %%
stems = set(stems)

filelist = [file for file in os.listdir('./review-files-python/')]

for file in filelist:

    print(file)
    # create a sample dataframe
    df = pd.read_csv('./review-files-python/' + file)
    # df = df.rename(columns={"review": "content", "score": "rating", "at": "date"})

    # define a set of strings to search for
    # stems = set(res) # {'apple', 'orange', 'mango'}
    #df['matched_stem'] = df['content'].str.findall('|'.join(stems)).apply(lambda x: ', '.join(x) if len(x) > 0 else None)
    #df = df.dropna()

    #df['matched_stem'] = df['content'].apply(lambda x: [] if x is None else [stem for stem in stems if stem in x])
    df['matched_stem'] = df['content'].apply(lambda x: [] if pd.isna(x) or x == '' else [stem for stem in stems if stem in x])
    
    df = df[df['matched_stem'].apply(len) > 0]
    df['matched_stem'] = df['matched_stem'].apply(lambda x: ', '.join(x))
    
    output_file = os.path.splitext(file)[0] + "_stems.csv"
    
    df.to_csv('review-files-python-stems/' + output_file, index=False)

    print('Stem matching completed and saved to:', output_file)

# %%
with open('feature-synonyms.txt') as file:
    lines = file.read()

synonyms = [token.strip() for token in lines.split(",")]

print(synonyms)


filelist = [file for file in os.listdir('./review-files-python/')]


for file in filelist:

    print(file)
    # create a sample dataframe
    df = pd.read_csv('./review-files-python/' + file)
    # df = df.rename(columns={"review": "content", "score": "rating", "at": "date"})

    # define a set of strings to search for
    # stems = set(res) # {'apple', 'orange', 'mango'}
    #df['matched_stem'] = df['content'].str.findall('|'.join(stems)).apply(lambda x: ', '.join(x) if len(x) > 0 else None)
    #df = df.dropna()

    #df['matched_stem'] = df['content'].apply(lambda x: [] if x is None else [stem for stem in stems if stem in x])
    df['matched_synonym'] = df['content'].apply(lambda x: [] if pd.isna(x) or x == '' else [synonym for synonym in synonyms if synonym in x])
    
    df = df[df['matched_synonym'].apply(len) > 0]
    df['matched_synonym'] = df['matched_synonym'].apply(lambda x: ', '.join(x))
    
    output_file = os.path.splitext(file)[0] + "_synonyms.csv"
    
    df.to_csv('review-files-python-synonyms/' + output_file, index=False)

    print('Synonym matching completed and saved to:', output_file)
